# %%
import pandas as pd

# %%
recieps_df = pd.read_csv('df_recipes.csv')

# %%
recieps_df
# Out:
#                                             recipe_urls  \
# 0     https://www.jamieoliver.com/recipes/duck-recip...
# 1     https://www.jamieoliver.com/recipes/vegetable-...
# 2     https://www.jamieoliver.com/recipes/pasta-reci...
# 3     https://www.jamieoliver.com/recipes/vegetable-...
# 4     https://www.jamieoliver.com/recipes/chicken-re...
# ...                                                 ...
# 4642  https://www.allrecipes.com/recipe/213809/thai-...
# 4643  https://www.allrecipes.com/recipe/41751/delici...
# 4644  https://www.allrecipes.com/recipe/264507/spicy...
# 4645  https://www.allrecipes.com/recipe/264012/ajad-...
# 4646  https://www.allrecipes.com/recipe/240387/sweet...
#
#                                             recipe_name  \
# 0                         Roast duck with Marsala gravy
# 1                            Best-ever Brussels sprouts
# 2                         Beautiful courgette carbonara
# 3                            Roasted black bean burgers
# ...

# %%
images_df = pd.read_csv("update_recipe.csv")

# %%
images_df
# Out:
#       Unnamed: 0                                                url  \
# 0              0  https://www.allrecipes.com/thmb/WIlQY-VrNsP0PP...
# 1              1  https://www.allrecipes.com/thmb/Hl9v8AO3biNaBP...
# 2              2  https://www.allrecipes.com/thmb/SkzcSLR785nELR...
# 3              3  https://www.allrecipes.com/thmb/iFr5enAVUnnh9e...
# 4              4  https://www.allrecipes.com/thmb/ao9cL5lQ71kjnP...
# ...          ...                                                ...
# 3055        3055                                                NaN
# 3056        3056  https://www.allrecipes.com/thmb/yGWZy-RgcXW77m...
# 3057        3057  https://www.allrecipes.com/thmb/MLKsJy1WXizgkf...
# 3058        3058  https://www.allrecipes.com/thmb/A2ZD0Lu7HC9-yp...
# 3059        3059  https://www.allrecipes.com/thmb/4xhCeDW6r0LPK3...
#
#                                                  step_1  \
# 0     Combine 1 1/2 cups sugar, lukewarm water, and ...
# ...

# %%
merged_df = pd.merge(recieps_df, images_df, on='url', how='inner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 merged_df = pd.merge(recieps_df, images_df, on='url', how='inner')
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
# ...
